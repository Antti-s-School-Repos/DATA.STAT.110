# %% [markdown]
# 3. The company has large stores in Helsinki and Tampere. The company wanted to find the customer satisfaction of the stores.
# In the outlets of the stores, customers were able to express their satisfaction by the following type of survey (How satisfied were you with our customer service?)
#
# Below is given the subset of the data. Note that the coding of the variable sat-
# isfaction is in, some sense, descending order. The file customersurvey.sav con-
# tains the whole data of the survey.
#
# location:
# Helsinki = 1
# Tampere = 2
#
# satisfaction:
# Very satisfied = 1
# Satisfied = 2
# Neither satisfied nor dissatisfied = 3
# Dissatisfied = 4
# Very dissatisfied = 5
#
# | Id   | location | satisfaction |
# |------|----------|--------------|
# | 1    | 1        | 2            |
# | 2    | 1        | 1            |
# | 3    | 1        | 4            |
# | 4    | 1        | 4            |
# | 5    | 1        | 1            |
# | 6    | 1        | 4            |
# | ...  | ...      | ...          |
# | 7549 | 2        | 4            |
# | 7550 | 2        | 3            |

# %% [markdown]
# a) What kind of variable Y =satisfaction is in this study?
# i. Explanatory variable defined on ordinal scale.
# ii. Response variable defined on ordinal scale.
# iii. Numerical explanatory variable.
# iv. Numerical response variable.

# %% [markdown]
# b) Consider the frequency distribution of the variable Y = satisfaction without
# considering the effect of the variable X = location on the analysis. Denote
# the frequency of the value y = 1 = "Very satisfied" by the symbol f1.
#
# What is the value of f1?

# %% [markdown]
# c) Consider the frequency distribution of the variable Y = satisfaction without
# considering the effect of the variable X = location on the analysis. Denote
# the relative frequency of the value y = 5 = "Very dissatisfied" by the symbol p5.
# What is the value of p5?

# %% [markdown]
# d) Consider the frequency distribution of the variable Y = satisfaction without
# considering the effect of the variable X = location on the analysis. Denote
# the cumulative relative frequency of the value y = 4 = "Dissatisfied" by the symbol P4.
#
# What is the value of P4?
